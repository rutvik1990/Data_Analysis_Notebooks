# %% [markdown]
# <a href="https://colab.research.google.com/github/rutvik1990/Data_Analysis_Notebooks/blob/main/Pnadas_Movie_Analysis/Movies_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
movies_sheet1 = pd.read_excel("C:\\Users\\PC\\Desktop\\DataFiles for Workshop\\movies.xls")

# %%
movies_sheet1.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings     ...      \
# 0          1.33   385907.0             NaN     ...
# 1          1.33   100000.0       3000000.0     ...
# ...

# %%
movies_sheet1 = pd.read_excel("C:\\Users\\PC\\Desktop\\DataFiles for Workshop\\movies.xls", sheetname=0, index_col=0)
movies_sheet1.head()
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
#                                                    Year               Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916    Drama|History|War
# Over the Hill to the Poorhouse                     1920          Crime|Drama
# The Big Parade                                     1925    Drama|Romance|War
# Metropolis                                         1927         Drama|Sci-Fi
# Pandora's Box                                      1929  Crime|Drama|Romance
#
#                                                   Language  Country  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# Over the Hill to the Poorhouse                         NaN      USA
# The Big Parade                                         NaN      USA
# ...

# %%
# Reading Sheet 2
movies_sheet2 = pd.read_excel("C:\\Users\\PC\\Desktop\\DataFiles for Workshop\\movies.xls", sheetname=1, index_col=0)
movies_sheet2.head()
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
#                         Year                   Genres Language Country  \
# Title
# 102 Dalmatians          2000  Adventure|Comedy|Family  English     USA
# 28 Days                 2000             Comedy|Drama  English     USA
# 3 Strikes               2000                   Comedy  English     USA
# Aberdeen                2000                    Drama  English      UK
# All the Pretty Horses   2000    Drama|Romance|Western  English     USA
#
#                        Content Rating  Duration  Aspect Ratio      Budget  \
# Title
# 102 Dalmatians                      G     100.0          1.85  85000000.0
# 28 Days                         PG-13     103.0          1.37  43000000.0
# 3 Strikes                           R      82.0          1.85   6000000.0
# Aberdeen                          NaN     106.0          1.85   6500000.0
# ...

# %%
#Sheet 3
movies_sheet3 = pd.read_excel("C:\\Users\\PC\\Desktop\\DataFiles for Workshop\\movies.xls", sheetname=2, index_col=0)
movies_sheet3.head()
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
#                                         Year  \
# Title
# 127 Hours                             2010.0
# 3 Backyards                           2010.0
# 3                                     2010.0
# 8: The Mormon Proposition             2010.0
# A Turtle's Tale: Sammy's Adventures   2010.0
#
#                                                                   Genres  \
# Title
# 127 Hours                             Adventure|Biography|Drama|Thriller
# 3 Backyards                                                        Drama
# 3                                                   Comedy|Drama|Romance
# 8: The Mormon Proposition                                    Documentary
# A Turtle's Tale: Sammy's Adventures           Adventure|Animation|Family
#
#                                      Language  Country Content Rating  \
# Title
# ...

# %%
#Concating all three sheets
movies = pd.concat([movies_sheet1, movies_sheet2, movies_sheet3])
movies.tail
# Out:
# <bound method NDFrame.tail of                                                      Year  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0
# Over the Hill to the Poorhouse                     1920.0
# The Big Parade                                     1925.0
# Metropolis                                         1927.0
# Pandora's Box                                      1929.0
# The Broadway Melody                                1929.0
# Hell's Angels                                      1930.0
# A Farewell to Arms                                 1932.0
# 42nd Street                                        1933.0
# She Done Him Wrong                                 1933.0
# It Happened One Night                              1934.0
# Top Hat                                            1935.0
# Modern Times                                       1936.0
# The Charge of the Light Brigade                    1936.0
# ...

# %%
movies.shape
# Out:
# (5042, 24)

# %%
xlsx = pd.ExcelFile("C:\\Users\\PC\\Desktop\\DataFiles for Workshop\\movies.xls")
#xlsx = pd.ExcelFile(excel_file)
movies_sheets = []
for sheet in xlsx.sheet_names:
    movies_sheets.append(xlsx.parse(sheet))
movies = pd.concat(movies_sheets)
movies
# Out:
#                                                   Title    Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916.0
# 1                       Over the Hill to the Poorhouse   1920.0
# 2                                       The Big Parade   1925.0
# 3                                           Metropolis   1927.0
# 4                                        Pandora's Box   1929.0
# 5                                  The Broadway Melody   1929.0
# 6                                        Hell's Angels   1930.0
# 7                                   A Farewell to Arms   1932.0
# 8                                          42nd Street   1933.0
# 9                                   She Done Him Wrong   1933.0
# 10                               It Happened One Night   1934.0
# 11                                             Top Hat   1935.0
# 12                                        Modern Times   1936.0
# 13                     The Charge of the Light Brigade   1936.0
# ...

# %%
#Exploring Data 
movies.shape
movies.tail()
# Out:
#                                      Title  Year  \
# 1599              War & Peace                NaN
# 1600                    Wings                NaN
# 1601               Wolf Creek                NaN
# 1602        Wuthering Heights                NaN
# 1603  Yu-Gi-Oh! Duel Monsters                NaN
#
#                                          Genres  Language    Country  \
# 1599                  Drama|History|Romance|War   English         UK
# 1600                               Comedy|Drama   English        USA
# 1601                      Drama|Horror|Thriller   English  Australia
# 1602                              Drama|Romance   English         UK
# 1603  Action|Adventure|Animation|Family|Fantasy  Japanese      Japan
#
#      Content Rating  Duration  Aspect Ratio  Budget  Gross Earnings  \
# 1599          TV-14       NaN         16.00     NaN             NaN
# 1600            NaN      30.0          1.33     NaN             NaN
# ...

# %%
sorted_by_gross = movies.sort_values(['Gross Earnings'], ascending=False)
sorted_by_gross
sorted_by_gross["Gross Earnings"].head(10)#top 10
# Out:
# 1867    760505847.0
# 1027    658672302.0
# 1263    652177271.0
# 610     623279547.0
# 611     623279547.0
# 1774    533316061.0
# 1281    474544677.0
# 226     460935665.0
# 1183    458991599.0
# 618     448130642.0
# Name: Gross Earnings, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
sorted_by_gross['Gross Earnings'].head(10).plot(kind="barh")

# %%
#creating a historam
movies['IMDB Score'].plot(kind="hist")
plt.show()

# %%
movies.describe()
# Out:
#               Year     Duration  Aspect Ratio        Budget  Gross Earnings  \
# count  4935.000000  5028.000000   4714.000000  4.551000e+03    4.159000e+03
# mean   2002.470517   107.201074      2.220403  3.975262e+07    4.846841e+07
# std      12.474599    25.197441      1.385113  2.061149e+08    6.845299e+07
# min    1916.000000     7.000000      1.180000  2.180000e+02    1.620000e+02
# 25%    1999.000000    93.000000      1.850000  6.000000e+06    5.340988e+06
# 50%    2005.000000   103.000000      2.350000  2.000000e+07    2.551750e+07
# 75%    2011.000000   118.000000      2.350000  4.500000e+07    6.230944e+07
# max    2016.000000   511.000000     16.000000  1.221550e+10    7.605058e+08
#
#        Facebook Likes - Director  Facebook Likes - Actor 1  \
# count                4938.000000               5035.000000
# mean                  686.621709               6561.323932
# std                  2813.602405              15021.977635
# ...

# %%
movies["Gross Earnings"].mean()# indivisual Method
# Out:
# 48468407.52680933

# %%
# skip the Header
movies_skip_rows = pd.read_excel("C:\\Users\\PC\\Desktop\\DataFiles for Workshop\\movies.xls", header=None, skiprows=4)
movies_skip_rows.head(5)
# Out:
#                      0     1                    2        3        4   \
# 0           Metropolis   1927         Drama|Sci-Fi   German  Germany
# 1        Pandora's Box   1929  Crime|Drama|Romance   German  Germany
# 2  The Broadway Melody   1929      Musical|Romance  English      USA
# 3        Hell's Angels   1930            Drama|War  English      USA
# 4   A Farewell to Arms   1932    Drama|Romance|War  English      USA
#
#           5    6     7          8          9  ...    15   16    17    18  \
# 0  Not Rated  145  1.33  6000000.0    26435.0 ...   136   23  18.0   203
# 1  Not Rated  110  1.33        NaN     9950.0 ...   426   20   3.0   455
# 2     Passed  100  1.37   379000.0  2808000.0 ...    77   28   4.0   109
# 3     Passed   96  1.20  3950000.0        NaN ...   431   12   4.0   457
# 4    Unrated   79  1.37   800000.0        NaN ...   998  164  99.0  1284
#
#       19  20      21   22     23   24
# 0  12000   1  111841  413  260.0  8.3
# ...

# %%
movies_skip_rows.columns = ['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
       'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
       'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
       'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
       'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
       'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
       'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score']
movies_skip_rows.head()
# Out:
#                   Title  Year               Genres Language  Country  \
# 0           Metropolis   1927         Drama|Sci-Fi   German  Germany
# 1        Pandora's Box   1929  Crime|Drama|Romance   German  Germany
# 2  The Broadway Melody   1929      Musical|Romance  English      USA
# 3        Hell's Angels   1930            Drama|War  English      USA
# 4   A Farewell to Arms   1932    Drama|Romance|War  English      USA
#
#   Content Rating  Duration  Aspect Ratio     Budget  Gross Earnings  \
# 0      Not Rated       145          1.33  6000000.0         26435.0
# 1      Not Rated       110          1.33        NaN          9950.0
# 2         Passed       100          1.37   379000.0       2808000.0
# 3         Passed        96          1.20  3950000.0             NaN
# 4        Unrated        79          1.37   800000.0             NaN
#
#       ...     Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 0     ...                          136                       23
# ...

# %%
#Reading Onl six columns
movies_subset_columns = pd.read_excel("C:\\Users\\PC\\Desktop\\DataFiles for Workshop\\movies.xls", parse_cols=6)
movies_subset_columns.head()
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110

# %%
#Create New Column by appltying Frmula 
movies["Net Earnings"] = movies["Gross Earnings"] - movies["Budget"]

# %%
movies
# Out:
#                                                   Title    Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916.0
# 1                       Over the Hill to the Poorhouse   1920.0
# 2                                       The Big Parade   1925.0
# 3                                           Metropolis   1927.0
# 4                                        Pandora's Box   1929.0
# 5                                  The Broadway Melody   1929.0
# 6                                        Hell's Angels   1930.0
# 7                                   A Farewell to Arms   1932.0
# 8                                          42nd Street   1933.0
# 9                                   She Done Him Wrong   1933.0
# 10                               It Happened One Night   1934.0
# 11                                             Top Hat   1935.0
# 12                                        Modern Times   1936.0
# 13                     The Charge of the Light Brigade   1936.0
# ...

# %%
#Sort Function
sorted_movies = movies[['Net Earnings']].sort_values(['Net Earnings'], ascending=[False])
sorted_movies.head(10)['Net Earnings'].plot.barh()
plt.show()
